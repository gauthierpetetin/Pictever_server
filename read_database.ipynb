# %%
from instant_server.db import models
models.connect(read_only=True)

# %%
tel1003 = models.PlatformInstance.objects(phone_num='00331003').first()
test1003 = models.User.objects(first_phone =tel1003.id).first()

# %%
print tel1003.reg_id
# Out:
# (null)

# %%
counter=0
for plat in models.PlatformInstance.objects():
    if plat.reg_id =="(null)":
        print plat.phone_num
# Out:
# 13472411845
# 0013472411845
# 0033658138781
# 0033636644658
# 0033636644658
# 0033636644658
# 000632550189
# 0033685909190
# 0033603250797
# 0033603250797
# 0033664701471
# 00123456789
# 0033636644658
# 0033636644658
# 0033636644658
# 0033636644658
# 0033636644658
# 0033636644658
# 0033636644658
# 0033636644658
# 0033664438819
# 0033636644658
# 0033611850107
# 0033648132146
# 0033678182628
# 0033778320094
# 000648114833
# 0033687362551
# 0033650356024
# 0033686335561
# 0033678354736
# 0033630359125
# 0033786629950
# 0033634452808
# 0033622226162
# 0033621748153
# 0033679996678
# 0033650403317
# 0033642125177
# 0033647161151
# 0033679476108
# 0033647412137
# 0033677830214
# 0033634452808
# 000671185483
# 0033635576938
# 0033638740953
# 0033674461270
# 0033667827577
# 0033623457970
# 0014087590964
# 0033603451200
# 004646709994586
# 0033647161151
# 0033635576938
# 0033658528107
# 0033672968425
# 0033610298504
# 00447522176227
# 0033674654140
# 0033619912860
# 0033628023492
# ...

# %%
for u in models.User.objects():
    print u.created_at
# Out:
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# 2014-10-01 02:00:00
# ...

# %%
for p in models.PlatformInstance.objects(phone_num='0016786088651'):
    u = models.User.objects.with_id(p.user_id)
    print u.email
# Out:
# mannyfreshdabest@yahoo.com

# %%
margaux = models.User.objects.with_id('54298fbe3425f80009a99104')
print margaux.email
# Out:
# margchop@gmail.com
